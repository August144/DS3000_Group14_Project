# %%
import pandas as pd

# %%
df = pd.read_csv("song_chars.csv")
df = df.iloc[:, 3:]
df.rename({"season": "target"}, axis=1, inplace=True)
df.drop(["song_name", "artist"], axis=1, inplace=True)

# %%
df
# Out:
#        target  danceability  energy    key  speechiness  acousticness  \
# 0      Winter         0.754   0.819      C       0.1120        0.0684
# 1      Winter         0.691   0.764      A       0.0386        0.1120
# 2      Winter         0.661   0.346      B       0.0300        0.4520
# 3      Winter         0.610   0.497      A       0.0279        0.3200
# 4      Winter         0.590   0.666      E       0.0244        0.1560
# ...       ...           ...     ...    ...          ...           ...
# 21045    Fall         0.776   0.808      B       0.1170        0.0297
# 21046    Fall         0.855   0.488  D#/Eb       0.2080        0.5060
# 21047    Fall         0.797   0.631  D#/Eb       0.0786        0.0904
# 21048    Fall         0.792   0.548      E       0.0820        0.0784
# 21049    Fall         0.712   0.703      E       0.1990        0.0287
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# ...

# %%
target_map = {"Winter": 0, "Spring": 1, "Summer": 2, "Fall": 3}
